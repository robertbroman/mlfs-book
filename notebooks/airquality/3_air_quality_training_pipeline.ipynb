# %%
import sys
from pathlib import Path
import os

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
from mlfs import config
if os.path.exists(f"{root_dir}/.env"):
    settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: c:\Users\rober\Documents\Skola\ID2223\mlfs-book
# HopsworksSettings initialized!

# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#333;">Training Pipeline</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Select features for the model and create a Feature View with the selected features
# 2. Create training data using the feature view
# 3. Train model
# 4. Evaluate model performance
# 5. Save model to model registry

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, r2_score
import hopsworks
from mlfs.airquality import util
import json

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
# Check if HOPSWORKS_API_KEY env variable is set or if it is set in ~/.env
if settings.HOPSWORKS_API_KEY is not None:
    api_key = settings.HOPSWORKS_API_KEY.get_secret_value()
    os.environ['HOPSWORKS_API_KEY'] = api_key
project = hopsworks.login()
fs = project.get_feature_store() 

secrets = hopsworks.get_secrets_api()
#location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
#location = json.loads(location_str)
#country=location['country']
#city=location['city']
#street=location['street']

with open(f"{root_dir}\\notebooks\\airquality\\locations.json") as f:
    locations = json.load(f)
# Pick location id for each training run
location = locations[2]

aqicn_url = location["aqicn_url"]
country = location["country"]
city = location["city"]
street = location["street"]
# Out:
# 2025-11-18 16:35:04,162 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2025-11-18 16:35:04,216 INFO: Initializing external client
# 2025-11-18 16:35:04,218 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-18 16:35:05,552 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1286331

# %%
# Retrieve feature groups
air_quality_fg = fs.get_feature_group(
    name='air_quality',
    version=2,
)
weather_fg = fs.get_feature_group(
    name='weather',
    version=2,
)

# %%
air_quality_fg.filter(air_quality_fg.country == country and air_quality_fg.city == city and air_quality_fg.street == street)

# %% [markdown]
# ---
#
# ## <span style="color:#ff5f27;"> 🖍 Feature View Creation and Retrieving </span>

# %%
# Select features for training data.
selected_features = air_quality_fg.select(['pm25', "lag_1_day", "lag_2_day", "lag_3_day", 'date']).join(weather_fg.select_features(), on=['city'])
# Out:
# 2025-11-18 16:35:07,695 INFO: Using ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant'] from feature group `weather` as features for the query. To include primary key and event time use `select_all`.

# %% [markdown]
# ### Feature Views
#
# `Feature Views` are selections of features from different **Feature Groups** that make up the input and output API (or schema) for a model. A **Feature Views** can create **Training Data** and also be used in Inference to retrieve inference data.
#
# The Feature Views allows a schema in form of a query with filters, defining a model target feature/label and additional transformation functions (declarative feature encoding).
#
# In order to create Feature View we can use `FeatureStore.get_or_create_feature_view()` method.
#
# You can specify the following parameters:
#
# - `name` - name of a feature group.
#
# - `version` - version of a feature group.
#
# - `labels`- our target variable.
#
# - `transformation_functions` - declarative feature encoding (not used here)
#
# - `query` - selected features/labels for the model

# %%
feature_view = fs.get_or_create_feature_view(
    name='air_quality_fv',
    description="weather features with air quality as the target",
    version=2,
    labels=['pm25'],
    query=selected_features,
)

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Split the training data into train/test data sets </span>
#
# We use a time-series split here, with training data before this date `start_date_test_data` and test data after this date

# %%
start_date_test_data = "2025-05-01"
# Convert string to datetime object
test_start = datetime.strptime(start_date_test_data, "%Y-%m-%d")

# %%
X_train, X_test, y_train, y_test = feature_view.train_test_split(
    test_start=test_start
)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.85s)

# %%
X_train
# Out:
#        lag_1_day  lag_2_day  lag_3_day                       date  \
# 0           18.0       24.0       56.0  2014-01-04 00:00:00+00:00
# 1           18.0       24.0       56.0  2014-01-04 00:00:00+00:00
# 2           18.0       24.0       56.0  2014-01-04 00:00:00+00:00
# 3           28.0       18.0       24.0  2014-01-05 00:00:00+00:00
# 4           28.0       18.0       24.0  2014-01-05 00:00:00+00:00
# ...          ...        ...        ...                        ...
# 11578       45.0       49.0       49.0  2025-04-29 00:00:00+00:00
# 11579       45.0       49.0       49.0  2025-04-29 00:00:00+00:00
# 11580       10.0       45.0       49.0  2025-04-30 00:00:00+00:00
# 11581       10.0       45.0       49.0  2025-04-30 00:00:00+00:00
# 11582       10.0       45.0       49.0  2025-04-30 00:00:00+00:00
#
#        temperature_2m_mean  precipitation_sum  wind_speed_10m_max  \
# 0                 2.914916           0.000000           19.171478
# 1                 2.914916           0.000000           19.171478
# 2                 2.914916           0.000000           19.171478
# 3                 1.735750           0.000000           17.102840
# 4                 1.735750           0.000000           17.102840
# ...                    ...                ...                 ...
# 11578             7.670834          13.199999           25.241108
# 11579             7.670834          13.199999           25.241108
# 11580             6.760418           5.900000           23.942705
# 11581             6.760418           5.900000           23.942705
# 11582             6.760418           5.900000           23.942705
#
#        wind_direction_10m_dominant
# 0                       148.867828
# 1                       148.867828
# 2                       148.867828
# 3                       143.829117
# 4                       143.829117
# ...                            ...
# 11578                   272.918243
# 11579                   272.918243
# 11580                   268.925659
# 11581                   268.925659
# 11582                   268.925659
#
# [11583 rows x 8 columns]

# %%
X_features = X_train.drop(columns=['date'])
X_test_features = X_test.drop(columns=['date'])

# %%
y_train
# Out:
#        pm25
# 0      28.0
# 1      28.0
# 2      28.0
# 3      30.0
# 4      30.0
# ...     ...
# 11578  10.0
# 11579  10.0
# 11580  13.0
# 11581  13.0
# 11582  13.0
#
# [11583 rows x 1 columns]

# %% [markdown]
# The `Feature View` is now saved in Hopsworks and you can retrieve it using `FeatureStore.get_feature_view(name='...', version=1)`.

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#ff5f27;">🧬 Modeling</span>
#
# We will train a regression model to predict pm25 using our 4 features (wind_speed, wind_dir, temp, precipitation)

# %%
# Creating an instance of the XGBoost Regressor
xgb_regressor = XGBRegressor()

# Fitting the XGBoost Regressor to the training data
xgb_regressor.fit(X_features, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Predicting target values on the test set
y_pred = xgb_regressor.predict(X_test_features)

# Calculating Mean Squared Error (MSE) using sklearn
mse = mean_squared_error(y_test.iloc[:,0], y_pred)
print("MSE:", mse)

# Calculating R squared using sklearn
r2 = r2_score(y_test.iloc[:,0], y_pred)
print("R squared:", r2)
# Out:
# MSE: 102.43836
# R squared: -0.055170437925816884

# %%
df = y_test
df['predicted_pm25'] = y_pred

# %%
df['date'] = X_test['date']
df = df.sort_values(by=['date'])
df.head(5)
# Out:
#        pm25  predicted_pm25                       date
# 11583  14.0       22.653368  2025-05-01 00:00:00+00:00
# 11584  14.0       22.653368  2025-05-01 00:00:00+00:00
# 11585  14.0       22.653368  2025-05-01 00:00:00+00:00
# 11586   9.0       10.946842  2025-05-02 00:00:00+00:00
# 11587   9.0       10.946842  2025-05-02 00:00:00+00:00

# %%
# Creating a directory for the model artifacts if it doesn't exist
model_dir = "air_quality_model"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
images_dir = model_dir + "/images"
if not os.path.exists(images_dir):
    os.mkdir(images_dir)

# %%
file_path = images_dir + f"/pm25_hindcast_{city}_{street}.png"
plt = util.plot_air_quality_forecast(city, street, df, file_path, hindcast=True) 
plt.show()

# %%
# Plotting feature importances using the plot_importance function from XGBoost
plot_importance(xgb_regressor)
feature_importance_path = images_dir + f"/feature_importance_{city}_{street}.png"
plt.savefig(feature_importance_path)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'>🗄 Model Registry</span>
#
# One of the features in Hopsworks is the model registry. This is where you can store different versions of models and compare their performance. Models from the registry can then be served as API endpoints.

# %%
# Saving the XGBoost regressor object as a json file in the model directory
xgb_regressor.save_model(model_dir + f"/model_{city}_{street}.json")

# %%
res_dict = { 
        "MSE": str(mse),
        "R squared": str(r2),
    }

# %%
mr = project.get_model_registry()

# Creating a Python model in the model registry named 'air_quality_xgboost_model'

aq_model = mr.python.create_model(
    name=f"air_quality_xgboost_model_{city}_{street}", 
    metrics= res_dict,
    feature_view=feature_view,
    description="Air Quality (PM2.5) predictor",
)

# Saving the model artifacts to the 'air_quality_model' directory in the model registry
aq_model.save(model_dir)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model/model.json: 0…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model/model_Trondhe…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model/model_Trondhe…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model/model_Trondhe…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/featur…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/featur…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/featur…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/featur…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/pm25_h…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/pm25_h…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/pm25_h…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\air_quality_model\images/pm25_h…
# Uploading c:\Users\rober\Documents\Skola\ID2223\mlfs-book\notebooks\airquality\model_schema.json: 0.000%|     …
# ---------------------------------------------------------------------------
# RestAPIError                              Traceback (most recent call last)
# Cell In[44], line 13
#       5 aq_model = mr.python.create_model(
#       6     name=f"air_quality_xgboost_model_{city}_{street}",
#       7     metrics= res_dict,
#       8     feature_view=feature_view,
#       9     description="Air Quality (PM2.5) predictor",
#      10 )
#      12 # Saving the model artifacts to the 'air_quality_model' directory in the model registry
# ---> 13 aq_model.save(model_dir)
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hopsworks_common\usage.py:246, in method_logger.<locals>.wrapper(*args, **kwargs)
#     244 except Exception as e:
#     245     exception = e
# --> 246     raise e
#     247 finally:
#     248     try:
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hopsworks_common\usage.py:242, in method_logger.<locals>.wrapper(*args, **kwargs)
#     239 exception = None
#     240 try:
#     241     # Call the original method
# --> 242     result = func(*args, **kwargs)
#     243     return result
#     244 except Exception as e:
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hsml\model.py:160, in Model.save(self, model_path, await_registration, keep_original_files, upload_configuration)
#     153     else:
#     154         warnings.warn(
#     155             "Model schema cannot not be inferred without both the feature view and the training dataset version.",
#     156             util.ProvenanceWarning,
#     157             stacklevel=1,
#     158         )
# --> 160 return self._model_engine.save(
#     161     model_instance=self,
#     162     model_path=model_path,
#     163     await_registration=await_registration,
#     164     keep_original_files=keep_original_files,
#     165     upload_configuration=upload_configuration,
#     166 )
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hsml\engine\model_engine.py:466, in ModelEngine.save(self, model_instance, model_path, await_registration, keep_original_files, upload_configuration)
#     464     except BaseException as be:
#     465         self._dataset_api.rm(model_instance.version_path)
# --> 466         raise be
#     468 print("Model created, explore it at " + model_instance.get_url())
#     470 return model_instance
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hsml\engine\model_engine.py:455, in ModelEngine.save(self, model_instance, model_path, await_registration, keep_original_files, upload_configuration)
#     453     model_instance = self._upload_additional_resources(model_instance)
#     454 if step["id"] == 3:
# --> 455     model_instance = self._model_api.put(
#     456         model_instance, model_query_params
#     457     )
#     458 if step["id"] == 4:
#     459     model_instance = self._poll_model_available(
#     460         model_instance, await_registration
#     461     )
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hsml\core\model_api.py:47, in ModelApi.put(self, model_instance, query_params)
#      37 path_params = [
#      38     "project",
#      39     _client._project_id,
#    (...)
#      43     model_instance.name + "_" + str(model_instance.version),
#      44 ]
#      45 headers = {"content-type": "application/json"}
#      46 return model_instance.update_from_response_json(
# ---> 47     _client._send_request(
#      48         "PUT",
#      49         path_params,
#      50         headers=headers,
#      51         query_params=query_params,
#      52         data=model_instance.json(),
#      53     )
#      54 )
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hopsworks_common\decorators.py:48, in connected.<locals>.if_connected(inst, *args, **kwargs)
#      46 if not inst._connected:
#      47     raise NoHopsworksConnectionError
# ---> 48 return fn(inst, *args, **kwargs)
#
# File c:\Users\rober\miniconda3\envs\id2223_py310\lib\site-packages\hopsworks_common\client\base.py:186, in Client._send_request(self, method, path_params, query_params, headers, data, stream, files, with_base_path_params)
#     181     response = self._retry_token_expired(
#     182         request, stream, self.TOKEN_EXPIRED_RETRY_INTERVAL, 1
#     183     )
#     185 if response.status_code // 100 != 2:
# --> 186     raise exceptions.RestAPIError(url, response)
#     188 if stream:
#     189     return response
#
# RestAPIError: Metadata operation error: (url: https://c.app.hopsworks.ai/hopsworks-api/api/project/1286331/modelregistries/1286331/models/air_quality_xgboost_model_Trondheim_Asveien%20skole_1). Server response:
# HTTP code: 422, HTTP reason: Unprocessable Entity, body: b'{"errorCode":120001,"usrMsg":"Model name must conform to regex: [a-zA-Z0-9_]+","errorMsg":"An argument was not provided or it was malformed."}', error code: 120001, error msg: An argument was not provided or it was malformed., user msg: Model name must conform to regex: [a-zA-Z0-9_]+

# %% [markdown]
# ---
# ## <span style="color:#ff5f27;">⏭️ **Next:** Part 04: Batch Inference</span>
#
# In the following notebook you will use your model for Batch Inference.
